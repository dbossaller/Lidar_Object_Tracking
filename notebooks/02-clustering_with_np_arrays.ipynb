# %% [markdown]
# ## Clustering with Numpy ##

# %%
import numpy as np
from lidar_object_tracking.config import PROCESSED_DATA_DIR
from lidar_object_tracking.dataset import json_to_numpy
from lidar_object_tracking.features import dbscan_clustering_labels,pull_clusters_fill_frames
from lidar_object_tracking.plots import plot_cluster_with_slider
# Out:
# 2026-03-05 20:02:55.866 | INFO     | lidar_object_tracking.config:<module>:11 - PROJ_ROOT path is: /home/danielb/Desktop/CodingProjects/lidar_object_tracking

# %%
dataset = json_to_numpy(PROCESSED_DATA_DIR,'004')

# %%
labels = dbscan_clustering_labels(dataset = dataset)
# Out:
# Found 12 clusters

# %%
filt = (labels == 6)

np.unique_counts(dataset[filt][:,0])
# Out:
# UniqueCountsResult(values=array([0.]), counts=array([56]))

# %%
processed_labeled_dataset = pull_clusters_fill_frames(dataset,labels, label = 6)

plot_cluster_with_slider(processed_labeled_dataset)
